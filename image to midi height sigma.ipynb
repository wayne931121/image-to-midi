# %%
"""
pip install matplotlib
git clone https://github.com/FlipperPA/midi-writer.git
cd midi-writer
pip install .
cd ..
jupyter notebook
"""
0
# Out:
# 0

# %%
from midi_writer import MIDIFile, Notes

_ = Notes()
k = _.__dict__ #note keys
n = sorted([_.__getattribute__(i) for i in k]) #key values

# %%
l = n[0]  #lowwer
u = n[-1] #upper
r = u-l  #range

# %%
import matplotlib.pyplot as plt
image = r"C:\Users\原神\Downloads\image (6).jpg"
image = plt.imread(image)

# %%
h,w,d = image.shape #heigth,width,depth

# %%
#create note values by image datas
ni = []
previous = 0
for i in range(previous, h, (h//r)+1):
  image_combine_height = image[i]
  for k in range(i-1,previous,-1):
      image_combine_height = image_combine_height+image[k]
  ct = image_combine_height #current image (current->ct)
  ni.append([])
  for j in range(0,w,(w//r)+1):
    ni[-1].append(ct[j])
  previous = i

# %%
ni
# Out:
# [[array([25, 33,  9], dtype=uint8),
#   array([127, 144,  74], dtype=uint8),
#   array([30, 41,  9], dtype=uint8),
#   array([48, 62, 11], dtype=uint8),
#   array([62, 76, 17], dtype=uint8),
#   array([59, 74, 17], dtype=uint8),
#   array([69, 84, 19], dtype=uint8),
#   array([75, 90, 25], dtype=uint8),
#   array([79, 95, 24], dtype=uint8),
#   array([64, 86, 21], dtype=uint8),
#   array([ 82, 105,  25], dtype=uint8),
#   array([159, 175,  76], dtype=uint8),
#   array([130, 146,  47], dtype=uint8),
#   array([157, 168,  74], dtype=uint8),
#   array([101, 116,  25], dtype=uint8),
#   array([106, 120,  25], dtype=uint8),
#   array([144, 159,  58], dtype=uint8),
#   array([248, 250, 237], dtype=uint8),
#   array([141, 154,  38], dtype=uint8),
#   array([146, 154,  35], dtype=uint8),
#   array([165, 173,  38], dtype=uint8),
#   array([187, 193,  67], dtype=uint8),
#   array([189, 195,  47], dtype=uint8),
#   array([237, 239, 104], dtype=uint8),
#   array([247, 248, 129], dtype=uint8),
#   array([247, 248, 120], dtype=uint8),
#   array([255, 250, 156], dtype=uint8),
#   array([255, 251, 164], dtype=uint8),
#   array([214, 228, 254], dtype=uint8),
#   array([204, 228, 254], dtype=uint8),
#   array([203, 229, 254], dtype=uint8),
#   array([201, 227, 254], dtype=uint8),
#   array([201, 228, 255], dtype=uint8),
#   array([197, 227, 253], dtype=uint8),
#   array([199, 226, 255], dtype=uint8),
#   array([198, 225, 254], dtype=uint8),
#   array([197, 228, 255], dtype=uint8),
#   array([198, 228, 255], dtype=uint8),
#   array([200, 227, 255], dtype=uint8),
#   array([198, 228, 255], dtype=uint8),
#   array([197, 226, 255], dtype=uint8),
#   array([202, 228, 253], dtype=uint8),
#   array([228, 231, 210], dtype=uint8),
#   array([255, 254, 172], dtype=uint8),
#   array([254, 255, 162], dtype=uint8),
#   array([254, 253, 161], dtype=uint8),
#   array([233, 240, 147], dtype=uint8),
#   array([251, 245, 147], dtype=uint8),
#   array([160, 183,  75], dtype=uint8),
#   array([138, 170,  61], dtype=uint8),
#   array([238, 241, 138], dtype=uint8),
#   array([234, 242, 130], dtype=uint8),
#   array([237, 246, 127], dtype=uint8),
#   array([132, 157,  63], dtype=uint8),
#   array([255, 250, 146], dtype=uint8),
#   array([255, 252, 134], dtype=uint8),
#   array([240, 240, 110], dtype=uint8),
#   array([208, 219,  81], dtype=uint8),
#   array([190, 210,  63], dtype=uint8),
#   array([102, 137,  33], dtype=uint8),
#   array([145, 163,  41], dtype=uint8),
#   array([150, 170,  47], dtype=uint8),
#   array([137, 160,  44], dtype=uint8),
#   array([ 81, 106,  25], dtype=uint8),
#   array([107, 132,  49], dtype=uint8),
#   array([65, 91, 17], dtype=uint8),
#   array([143, 176,  59], dtype=uint8),
#   array([ 80, 108,  23], dtype=uint8),
#   array([57, 84,  5], dtype=uint8),
#   array([20, 24,  0], dtype=uint8),
#   array([16, 18,  4], dtype=uint8),
#   array([49, 73,  0], dtype=uint8),
#   array([ 78, 107,   1], dtype=uint8),
#   array([63, 88,  5], dtype=uint8),
#   array([62, 85,  3], dtype=uint8),
#   array([58, 88,  2], dtype=uint8),
#   array([ 67, 104,   0], dtype=uint8),
#   array([46, 83,  6], dtype=uint8),
#   array([45, 81,  9], dtype=uint8)],
#  [array([145,  90, 247], dtype=uint8),
#   array([104,  94, 200], dtype=uint8),
#   array([181,  72,  99], dtype=uint8),
#   array([193, 116, 150], dtype=uint8),
#   array([198, 140, 147], dtype=uint8),
#   array([  4, 212, 190], dtype=uint8),
#   array([123,  69, 209], dtype=uint8),
#   array([  2, 201, 151], dtype=uint8),
#   array([229, 210, 240], dtype=uint8),
#   array([152, 237,  83], dtype=uint8),
#   array([ 98, 169, 161], dtype=uint8),
#   array([ 10,  16, 196], dtype=uint8),
#   array([110,  56, 103], dtype=uint8),
#   array([170,  89,  25], dtype=uint8),
#   array([104,  20, 200], dtype=uint8),
#   array([ 68,  10, 105], dtype=uint8),
#   array([222, 132, 133], dtype=uint8),
#   array([215,  79,  31], dtype=uint8),
#   array([166,  37,  28], dtype=uint8),
#   array([238, 112,  23], dtype=uint8),
#   array([179,  44, 217], dtype=uint8),
#   array([ 79, 178,  85], dtype=uint8),
#   array([232,  71,  86], dtype=uint8),
#   array([ 10,  65, 108], dtype=uint8),
#   array([ 46,  69, 128], dtype=uint8),
#   array([ 91, 103,  81], dtype=uint8),
#   array([177, 146, 151], dtype=uint8),
#   array([231, 180, 117], dtype=uint8),
#   array([175,  49, 110], dtype=uint8),
#   array([108, 163, 239], dtype=uint8),
#   array([ 37, 146, 228], dtype=uint8),
#   array([ 27, 135, 235], dtype=uint8),
#   array([ 29, 144, 238], dtype=uint8),
#   array([  6, 136, 235], dtype=uint8),
#   array([  2, 129, 237], dtype=uint8),
#   array([  0, 127, 236], dtype=uint8),
#   array([255, 142, 238], dtype=uint8),
#   array([  0, 144, 237], dtype=uint8),
#   array([247, 136, 240], dtype=uint8),
#   array([232, 134, 235], dtype=uint8),
#   array([217, 139, 204], dtype=uint8),
#   array([ 12, 146, 216], dtype=uint8),
#   array([ 64, 128,   5], dtype=uint8),
#   array([187, 185, 142], dtype=uint8),
#   array([222, 216,  34], dtype=uint8),
#   array([153, 184, 113], dtype=uint8),
#   array([245,  74,  66], dtype=uint8),
#   array([157, 155,  53], dtype=uint8),
#   array([240, 172, 119], dtype=uint8),
#   array([198, 152, 142], dtype=uint8),
#   array([164, 179,  86], dtype=uint8),
#   array([171, 175,  12], dtype=uint8),
#   array([182, 200, 157], dtype=uint8),
#   array([ 18,  29, 154], dtype=uint8),
#   array([233, 193,  28], dtype=uint8),
#   array([ 94,  85, 141], dtype=uint8),
#   array([ 42, 109,  25], dtype=uint8),
#   array([251, 242, 225], dtype=uint8),
#   array([223,  35, 248], dtype=uint8),
#   array([ 23, 171,  39], dtype=uint8),
#   array([ 10, 252, 146], dtype=uint8),
#   array([184, 236, 166], dtype=uint8),
#   array([ 55, 148, 142], dtype=uint8),
#   array([ 53, 161, 109], dtype=uint8),
#   array([ 19, 114, 108], dtype=uint8),
#   array([189,  81,  54], dtype=uint8),
#   array([167,  87, 206], dtype=uint8),
#   array([251, 169, 111], dtype=uint8),
#   array([154, 108,  88], dtype=uint8),
#   array([201,  76, 145], dtype=uint8),
#   array([173,  58, 220], dtype=uint8),
#   array([ 31, 148,  35], dtype=uint8),
#   array([ 33, 200,  42], dtype=uint8),
#   array([220,  70, 143], dtype=uint8),
#   array([117, 167, 179], dtype=uint8),
#   array([113,   5,  99], dtype=uint8),
#   array([158, 133, 171], dtype=uint8),
#   array([208, 160, 252], dtype=uint8),
#   array([166, 123, 248], dtype=uint8)],
#  [array([233, 166,   2], dtype=uint8),
#   array([226, 213, 123], dtype=uint8),
#   array([ 85,   0, 152], dtype=uint8),
#   array([ 49, 165, 112], dtype=uint8),
#   array([164,  65, 126], dtype=uint8),
#   array([146,  88, 145], dtype=uint8),
#   array([157, 118, 123], dtype=uint8),
#   array([ 49, 244, 203], dtype=uint8),
#   array([230, 219, 253], dtype=uint8),
#   array([112, 181, 164], dtype=uint8),
#   array([109, 199, 221], dtype=uint8),
#   array([ 69, 115, 142], dtype=uint8),
#   array([248, 216,  13], dtype=uint8),
#   array([233, 103, 223], dtype=uint8),
#   array([ 55, 147, 119], dtype=uint8),
#   array([  0, 113, 156], dtype=uint8),
#   array([ 70, 162,  96], dtype=uint8),
#   array([157, 240, 218], dtype=uint8),
#   array([178,  64, 156], dtype=uint8),
#   array([181, 252,  53], dtype=uint8),
#   array([181, 255, 112], dtype=uint8),
#   array([163,  31,  37], dtype=uint8),
#   array([ 66, 206,  19], dtype=uint8),
#   array([232,  76, 171], dtype=uint8),
#   array([159, 192, 188], dtype=uint8),
#   array([140, 182,  39], dtype=uint8),
#   array([214, 238, 191], dtype=uint8),
#   array([83, 89, 88], dtype=uint8),
#   array([218,  78, 243], dtype=uint8),
#   array([164, 210, 226], dtype=uint8),
#   array([123, 193, 240], dtype=uint8),
#   array([ 96, 203, 238], dtype=uint8),
#   array([ 97, 186, 238], dtype=uint8),
#   array([ 83, 198, 236], dtype=uint8),
#   array([ 70, 201, 238], dtype=uint8),
#   array([ 69, 200, 236], dtype=uint8),
#   array([ 74, 195, 240], dtype=uint8),
#   array([ 71, 196, 239], dtype=uint8),
#   array([ 57, 184, 233], dtype=uint8),
#   array([ 59, 174, 233], dtype=uint8),
#   array([ 33, 195, 215], dtype=uint8),
#   array([ 61, 214, 217], dtype=uint8),
#   array([ 18,  29, 166], dtype=uint8),
#   array([ 80,  57, 109], dtype=uint8),
#   array([249,  31, 194], dtype=uint8),
#   array([229,  88, 185], dtype=uint8),
#   array([150, 162,  41], dtype=uint8),
#   array([ 38,  82, 186], dtype=uint8),
#   array([ 95, 167, 197], dtype=uint8),
#   array([225, 195,   1], dtype=uint8),
#   array([229, 213, 162], dtype=uint8),
#   array([31, 88, 32], dtype=uint8),
#   array([148, 129,  15], dtype=uint8),
#   array([  5,  67, 202], dtype=uint8),
#   array([116, 184, 239], dtype=uint8),
#   array([212,  88, 194], dtype=uint8),
#   array([180, 221, 223], dtype=uint8),
#   array([ 73, 151,  77], dtype=uint8),
#   array([ 46, 172, 253], dtype=uint8),
#   array([132,  32,  72], dtype=uint8),
#   array([ 40, 191, 110], dtype=uint8),
#   array([102,  46, 163], dtype=uint8),
#   array([  2, 191, 179], dtype=uint8),
#   array([186,  70, 106], dtype=uint8),
#   array([119, 153,  77], dtype=uint8),
#   array([164, 151, 113], dtype=uint8),
#   array([104,  38, 252], dtype=uint8),
#   array([157,  90, 230], dtype=uint8),
#   array([ 17, 184,  18], dtype=uint8),
#   array([ 54, 188, 214], dtype=uint8),
#   array([171, 206, 114], dtype=uint8),
#   array([165, 198, 132], dtype=uint8),
#   array([23, 62, 19], dtype=uint8),
#   array([ 65, 237, 246], dtype=uint8),
#   array([180,  44, 208], dtype=uint8),
#   array([183,  93,  85], dtype=uint8),
#   array([ 97, 106, 117], dtype=uint8),
#   array([226, 244, 140], dtype=uint8),
#   array([210, 230, 212], dtype=uint8)],
#  [array([168,  62,  54], dtype=uint8),
#   array([127, 217,  75], dtype=uint8),
#   array([246,  75,   0], dtype=uint8),
#   array([118,  50,  59], dtype=uint8),
#   array([235, 139, 210], dtype=uint8),
#   array([238, 168,  75], dtype=uint8),
#   array([ 10, 203, 246], dtype=uint8),
#   array([219, 145,  48], dtype=uint8),
#   array([84, 59, 88], dtype=uint8),
#   array([123, 147, 202], dtype=uint8),
#   array([239,  34,  14], dtype=uint8),
#   array([  9,  66, 195], dtype=uint8),
#   array([45, 26, 81], dtype=uint8),
#   array([138,  48, 114], dtype=uint8),
#   array([ 25, 155,   8], dtype=uint8),
#   array([150, 251, 240], dtype=uint8),
#   array([200, 250, 140], dtype=uint8),
#   array([76, 69, 89], dtype=uint8),
#   array([108, 126, 162], dtype=uint8),
#   array([157, 116,  45], dtype=uint8),
#   array([104, 130, 152], dtype=uint8),
#   array([196,   3,  23], dtype=uint8),
#   array([169, 215,  81], dtype=uint8),
#   array([117, 251,  13], dtype=uint8),
#   array([157,  22,  21], dtype=uint8),
#   array([  5, 117, 131], dtype=uint8),
#   array([98, 34, 74], dtype=uint8),
#   array([ 83,  41, 132], dtype=uint8),
#   array([ 11,  13, 230], dtype=uint8),
#   array([230, 254, 235], dtype=uint8),
#   array([225, 249, 231], dtype=uint8),
#   array([197, 255, 237], dtype=uint8),
#   array([170, 240, 236], dtype=uint8),
#   array([154, 242, 237], dtype=uint8),
#   array([158, 254, 240], dtype=uint8),
#   array([154, 250, 238], dtype=uint8),
#   array([130, 245, 235], dtype=uint8),
#   array([139, 251, 233], dtype=uint8),
#   array([137, 252, 231], dtype=uint8),
#   array([136, 244, 220], dtype=uint8),
#   array([125, 233, 227], dtype=uint8),
#   array([121, 236, 221], dtype=uint8),
#   array([115, 233, 227], dtype=uint8),
#   array([114, 232, 228], dtype=uint8),
#   array([226, 101,  10], dtype=uint8),
#   array([178, 167,   9], dtype=uint8),
#   array([241, 197, 125], dtype=uint8),
#   array([233, 193,  55], dtype=uint8),
#   array([233, 189,  47], dtype=uint8),
#   array([157, 143,  86], dtype=uint8),
#   array([163, 175, 205], dtype=uint8),
#   array([160, 116, 205], dtype=uint8),
#   array([134, 205, 126], dtype=uint8),
#   array([133, 214, 180], dtype=uint8),
#   array([ 61, 132, 220], dtype=uint8),
#   array([158, 249,  94], dtype=uint8),
#   array([ 70, 181,  80], dtype=uint8),
#   array([106, 190,  24], dtype=uint8),
#   array([ 54,  37, 172], dtype=uint8),
#   array([ 29, 107, 149], dtype=uint8),
#   array([ 51,   9, 101], dtype=uint8),
#   array([166, 120,   3], dtype=uint8),
#   array([148,  87, 169], dtype=uint8),
#   array([205, 153, 202], dtype=uint8),
#   array([121,  65,  74], dtype=uint8),
#   array([30, 47, 29], dtype=uint8),
#   array([  2, 153, 214], dtype=uint8),
#   array([ 98, 149, 235], dtype=uint8),
#   array([ 44, 200, 144], dtype=uint8),
#   array([ 20, 184, 165], dtype=uint8),
#   array([147,  16,  90], dtype=uint8),
#   array([204, 201,  58], dtype=uint8),
#   array([102, 107, 124], dtype=uint8),
#   array([ 19, 175, 172], dtype=uint8),
#   array([224, 236,  70], dtype=uint8),
#   array([238,  10,  89], dtype=uint8),
#   array([125, 130,  25], dtype=uint8),
#   array([243,  52,  41], dtype=uint8),
#   array([ 90, 172,  72], dtype=uint8)],
#  [array([ 21, 179, 255], dtype=uint8),
#   array([ 52, 218,  12], dtype=uint8),
#   array([148,  75,  63], dtype=uint8),
#   array([ 17, 214,  88], dtype=uint8),
#   array([ 50, 230, 107], dtype=uint8),
#   array([238, 164,  94], dtype=uint8),
#   array([125,  35, 210], dtype=uint8),
#   array([130,  37, 244], dtype=uint8),
#   array([ 87, 255, 215], dtype=uint8),
#   array([134,  59,  31], dtype=uint8),
#   array([ 84,   6, 117], dtype=uint8),
#   array([173, 207, 152], dtype=uint8),
#   array([ 27,  23, 149], dtype=uint8),
#   array([134,  75, 238], dtype=uint8),
#   array([202, 127, 195], dtype=uint8),
#   array([239, 172,  42], dtype=uint8),
#   array([ 27, 139, 190], dtype=uint8),
#   array([203, 246,  80], dtype=uint8),
#   array([138, 167,   8], dtype=uint8),
#   array([ 25,  33, 228], dtype=uint8),
#   array([112,  94, 128], dtype=uint8),
#   array([160, 118,  74], dtype=uint8),
#   array([143, 116, 115], dtype=uint8),
#   array([ 64, 129,  42], dtype=uint8),
#   array([108,  65, 157], dtype=uint8),
#   array([ 95,  44, 238], dtype=uint8),
#   array([ 66,  36, 206], dtype=uint8),
#   array([ 61,  35, 235], dtype=uint8),
#   array([ 60,  37, 239], dtype=uint8),
#   array([ 37,  28, 240], dtype=uint8),
#   array([ 23,  28, 232], dtype=uint8),
#   array([ 18,  36, 237], dtype=uint8),
#   array([  3,  31, 236], dtype=uint8),
#   array([  1,  23, 235], dtype=uint8),
#   array([244,  40, 228], dtype=uint8),
#   array([137, 196,  11], dtype=uint8),
#   array([222, 203,  22], dtype=uint8),
#   array([ 47, 224,  71], dtype=uint8),
#   array([100, 194, 125], dtype=uint8),
#   array([129, 221,  44], dtype=uint8),
#   array([ 30, 122, 145], dtype=uint8),
#   array([ 33, 205, 134], dtype=uint8),
#   array([217, 159, 147], dtype=uint8),
#   array([177,  94, 195], dtype=uint8),
#   array([219, 235, 207], dtype=uint8),
#   array([192, 215,  51], dtype=uint8),
#   array([253,  71,  46], dtype=uint8),
#   array([ 33,  98, 240], dtype=uint8),
#   array([227,   0,  15], dtype=uint8),
#   array([ 92, 215, 199], dtype=uint8),
#   array([ 76, 255,   0], dtype=uint8),
#   array([165, 222,  16], dtype=uint8),
#   array([ 70, 239, 228], dtype=uint8),
#   array([ 16, 110, 100], dtype=uint8),
#   array([ 87,  39, 122], dtype=uint8),
#   array([128, 104, 186], dtype=uint8),
#   array([200, 109, 239], dtype=uint8),
#   array([123,  46,  19], dtype=uint8),
#   array([ 40, 199,  26], dtype=uint8),
#   array([50, 61, 64], dtype=uint8),
#   array([ 16,  62, 254], dtype=uint8),
#   array([158,  92,   7], dtype=uint8),
#   array([232, 163,  16], dtype=uint8),
#   array([ 15, 221,  23], dtype=uint8),
#   array([ 68, 239,  38], dtype=uint8),
#   array([177, 204,  45], dtype=uint8),
#   array([ 64, 210,  16], dtype=uint8),
#   array([218,  98, 152], dtype=uint8),
#   array([170,  87, 129], dtype=uint8),
#   array([156, 130, 108], dtype=uint8),
#   array([154,  42, 113], dtype=uint8),
#   array([ 35, 253,  95], dtype=uint8),
#   array([144, 101,  40], dtype=uint8),
#   array([169, 142,  35], dtype=uint8),
#   array([222, 220,  82], dtype=uint8),
#   array([211, 234,  97], dtype=uint8),
#   array([224, 234, 159], dtype=uint8),
#   array([129, 134,  87], dtype=uint8),
#   array([159, 254,  42], dtype=uint8)],
#  [array([ 80,  84, 215], dtype=uint8),
#   array([ 48, 223, 200], dtype=uint8),
#   array([ 61, 222, 140], dtype=uint8),
#   array([219, 134, 200], dtype=uint8),
#   array([210, 131,  57], dtype=uint8),
#   array([112,  33, 154], dtype=uint8),
#   array([233, 149, 110], dtype=uint8),
#   array([94, 22, 32], dtype=uint8),
#   array([239, 150, 166], dtype=uint8),
#   array([106, 223, 134], dtype=uint8),
#   array([135, 254, 243], dtype=uint8),
#   array([227, 224, 199], dtype=uint8),
#   array([110, 105,  79], dtype=uint8),
#   array([114,  95, 105], dtype=uint8),
#   array([ 21, 245, 239], dtype=uint8),
#   array([124,  54, 238], dtype=uint8),
#   array([ 25, 208, 199], dtype=uint8),
#   array([240, 131,  75], dtype=uint8),
#   array([185,  56, 197], dtype=uint8),
#   array([105, 177, 159], dtype=uint8),
#   array([ 32,  67, 151], dtype=uint8),
#   array([164, 183,  41], dtype=uint8),
#   array([11, 22, 15], dtype=uint8),
#   array([ 77, 104, 152], dtype=uint8),
#   array([244,  98, 159], dtype=uint8),
#   array([231,  86, 184], dtype=uint8),
#   array([216,  97,  35], dtype=uint8),
#   array([136,  59, 231], dtype=uint8),
#   array([113,  59, 232], dtype=uint8),
#   array([100,  54, 237], dtype=uint8),
#   array([ 99,  59, 236], dtype=uint8),
#   array([ 85,  61, 228], dtype=uint8),
#   array([ 73,  66, 201], dtype=uint8),
#   array([103,  15,  28], dtype=uint8),
#   array([204,  33, 135], dtype=uint8),
#   array([165, 157,  34], dtype=uint8),
#   array([148, 139,   8], dtype=uint8),
#   array([ 26,  51, 145], dtype=uint8),
#   array([ 55, 157, 192], dtype=uint8),
#   array([132, 193, 158], dtype=uint8),
#   array([ 40, 221, 189], dtype=uint8),
#   array([205, 167,  74], dtype=uint8),
#   array([ 16, 199, 217], dtype=uint8),
#   array([215, 100, 219], dtype=uint8),
#   array([240,  14, 123], dtype=uint8),
#   array([187, 203,  50], dtype=uint8),
#   array([202,  94,  13], dtype=uint8),
#   array([ 66, 254, 182], dtype=uint8),
#   array([ 58, 170, 131], dtype=uint8),
#   array([175, 154,  46], dtype=uint8),
#   array([107, 202, 156], dtype=uint8),
#   array([137, 205,  40], dtype=uint8),
#   array([118,  18,   1], dtype=uint8),
#   array([105,  67, 115], dtype=uint8),
#   array([ 98,  12, 170], dtype=uint8),
#   array([ 73,  47, 142], dtype=uint8),
#   array([  2, 190, 101], dtype=uint8),
#   array([ 50, 232, 188], dtype=uint8),
#   array([103,  22, 217], dtype=uint8),
#   array([204, 101,  87], dtype=uint8),
#   array([ 52, 101, 216], dtype=uint8),
#   array([114,  73, 142], dtype=uint8),
#   array([ 76, 254,  59], dtype=uint8),
#   array([194, 137, 143], dtype=uint8),
#   array([  9, 178, 142], dtype=uint8),
#   array([114, 255,  53], dtype=uint8),
#   array([174, 214,   3], dtype=uint8),
#   array([188, 239,   3], dtype=uint8),
#   array([198, 151, 187], dtype=uint8),
#   array([111, 130, 129], dtype=uint8),
#   array([49, 45, 52], dtype=uint8),
#   array([144, 193, 170], dtype=uint8),
#   array([202, 159,  75], dtype=uint8),
#   array([203, 167,  70], dtype=uint8),
#   array([ 20,  51, 201], dtype=uint8),
#   array([241,   3, 175], dtype=uint8),
#   array([ 53, 193,  87], dtype=uint8),
#   array([243,  59, 208], dtype=uint8),
#   array([ 30, 106, 242], dtype=uint8)],
#  [array([119,  57,  94], dtype=uint8),
#   array([ 92, 238, 108], dtype=uint8),
#   array([ 21, 173, 215], dtype=uint8),
#   array([ 86, 215, 132], dtype=uint8),
#   array([144,  28, 187], dtype=uint8),
#   array([  7, 157, 252], dtype=uint8),
#   array([  3, 162, 106], dtype=uint8),
#   array([195,  91,  37], dtype=uint8),
#   array([128,  50, 121], dtype=uint8),
#   array([211, 126, 146], dtype=uint8),
#   array([ 83,   6, 253], dtype=uint8),
#   array([209, 194, 178], dtype=uint8),
#   array([138, 128, 245], dtype=uint8),
#   array([228, 221, 196], dtype=uint8),
#   array([121, 111,   9], dtype=uint8),
#   array([169, 152, 149], dtype=uint8),
#   array([ 33, 229, 170], dtype=uint8),
#   array([207, 127, 242], dtype=uint8),
#   array([ 70,  17, 173], dtype=uint8),
#   array([241, 120,  78], dtype=uint8),
#   array([ 37, 160,  89], dtype=uint8),
#   array([ 80, 177,   5], dtype=uint8),
#   array([  7,  54, 113], dtype=uint8),
#   array([176, 196, 177], dtype=uint8),
#   array([245,  18, 169], dtype=uint8),
#   array([ 41,  67, 252], dtype=uint8),
#   array([122, 145, 134], dtype=uint8),
#   array([ 12, 114, 157], dtype=uint8),
#   array([180,  90, 239], dtype=uint8),
#   array([176,  89, 239], dtype=uint8),
#   array([180,  91, 204], dtype=uint8),
#   array([140,  20, 193], dtype=uint8),
#   array([ 25,  35, 247], dtype=uint8),
#   array([188, 154,  52], dtype=uint8),
#   array([131, 135, 224], dtype=uint8),
#   array([ 97, 110, 180], dtype=uint8),
#   array([115,  12,   4], dtype=uint8),
#   array([20, 23, 69], dtype=uint8),
#   array([198, 255, 184], dtype=uint8),
#   array([ 18, 204,  80], dtype=uint8),
#   array([92, 26, 21], dtype=uint8),
#   array([176,  24,  77], dtype=uint8),
#   array([196,  41,  24], dtype=uint8),
#   array([127,   9, 124], dtype=uint8),
#   array([ 97, 143,  14], dtype=uint8),
#   array([141,  32, 106], dtype=uint8),
#   array([ 24, 185,  75], dtype=uint8),
#   array([253, 236,  72], dtype=uint8),
#   array([225, 237,  73], dtype=uint8),
#   array([211, 247, 104], dtype=uint8),
#   array([  7,  17, 156], dtype=uint8),
#   array([  5, 152, 249], dtype=uint8),
#   array([142, 109,  94], dtype=uint8),
#   array([ 35, 215,   6], dtype=uint8),
#   array([229, 183, 106], dtype=uint8),
#   array([ 78,  35, 167], dtype=uint8),
#   array([ 45, 252, 125], dtype=uint8),
#   array([ 53,   1, 126], dtype=uint8),
#   array([220, 121, 228], dtype=uint8),
#   array([188,  70,  55], dtype=uint8),
#   array([ 77, 199, 254], dtype=uint8),
#   array([152, 166, 198], dtype=uint8),
#   array([ 85, 238,  94], dtype=uint8),
#   array([249,  60,  10], dtype=uint8),
#   array([149,  31, 212], dtype=uint8),
#   array([ 50, 204,  48], dtype=uint8),
#   array([203, 184, 160], dtype=uint8),
#   array([245,  53,   1], dtype=uint8),
#   array([48, 30, 84], dtype=uint8),
#   array([131, 127, 165], dtype=uint8),
#   array([92, 84, 93], dtype=uint8),
#   array([230,   2,  57], dtype=uint8),
#   array([ 49,  13, 135], dtype=uint8),
#   array([ 68,  65, 157], dtype=uint8),
#   array([210, 205,  50], dtype=uint8),
#   array([242,   8, 168], dtype=uint8),
#   array([ 38, 191, 181], dtype=uint8),
#   array([  2,  76, 212], dtype=uint8),
#   array([157, 199, 111], dtype=uint8)],
#  [array([209,  38,  46], dtype=uint8),
#   array([ 60, 226, 184], dtype=uint8),
#   array([218, 247, 227], dtype=uint8),
#   array([231, 138, 254], dtype=uint8),
#   array([22, 83,  7], dtype=uint8),
#   array([179, 235, 104], dtype=uint8),
#   array([ 54, 230, 190], dtype=uint8),
#   array([ 75, 248, 196], dtype=uint8),
#   array([ 62,  11, 233], dtype=uint8),
#   array([144,  41, 166], dtype=uint8),
#   array([ 43, 187, 183], dtype=uint8),
#   array([152, 210, 121], dtype=uint8),
#   array([196,  86, 221], dtype=uint8),
#   array([128,  15, 238], dtype=uint8),
#   array([189, 191, 167], dtype=uint8),
#   array([206, 245, 236], dtype=uint8),
#   array([160, 184,  38], dtype=uint8),
#   array([ 55, 106, 183], dtype=uint8),
#   array([ 66, 103, 157], dtype=uint8),
#   array([171, 161,  87], dtype=uint8),
#   array([109,  18,  51], dtype=uint8),
#   array([247, 135, 111], dtype=uint8),
#   array([158,  17, 157], dtype=uint8),
#   array([252,  44, 104], dtype=uint8),
#   array([114, 159, 137], dtype=uint8),
#   array([243,   3,  48], dtype=uint8),
#   array([ 83, 117, 152], dtype=uint8),
#   array([21, 91, 85], dtype=uint8),
#   array([243, 116, 230], dtype=uint8),
#   array([112, 203,  64], dtype=uint8),
#   array([12, 40, 39], dtype=uint8),
#   array([207, 168,  44], dtype=uint8),
#   array([ 87,  87, 126], dtype=uint8),
#   array([ 1, 39, 34], dtype=uint8),
#   array([ 69, 215, 116], dtype=uint8),
#   array([145,  82, 247], dtype=uint8),
#   array([ 20, 134, 112], dtype=uint8),
#   array([ 48, 128,  93], dtype=uint8),
#   array([ 27, 166, 143], dtype=uint8),
#   array([209, 178, 143], dtype=uint8),
#   array([228, 129, 112], dtype=uint8),
#   array([152,  57,  89], dtype=uint8),
#   array([175, 254,  78], dtype=uint8),
#   array([146,  69,  62], dtype=uint8),
#   array([ 81, 238,  25], dtype=uint8),
#   array([243, 230,  66], dtype=uint8),
#   array([174, 162,  21], dtype=uint8),
#   array([158,  51, 253], dtype=uint8),
#   array([175,  54,  65], dtype=uint8),
#   array([167, 219, 115], dtype=uint8),
#   array([165, 191, 113], dtype=uint8),
#   array([158, 196, 142], dtype=uint8),
#   array([202,  27, 237], dtype=uint8),
#   array([231, 209, 121], dtype=uint8),
#   array([113,  99, 144], dtype=uint8),
#   array([214, 133, 178], dtype=uint8),
#   array([170,   4,  76], dtype=uint8),
#   array([159, 109,  38], dtype=uint8),
#   array([128,  68,  18], dtype=uint8),
#   array([105,   0, 204], dtype=uint8),
#   array([214, 231,  71], dtype=uint8),
#   array([168, 128, 172], dtype=uint8),
#   array([171,  90, 181], dtype=uint8),
#   array([146, 219,  62], dtype=uint8),
#   array([  4, 185, 172], dtype=uint8),
#   array([139, 213, 246], dtype=uint8),
#   array([ 47,  98, 110], dtype=uint8),
#   array([245, 255, 255], dtype=uint8),
#   array([ 46,  34, 236], dtype=uint8),
#   array([162, 117, 221], dtype=uint8),
#   array([150,  76, 142], dtype=uint8),
#   array([211, 100,   4], dtype=uint8),
#   array([194, 170, 208], dtype=uint8),
#   array([251, 209, 103], dtype=uint8),
#   array([ 54,  12, 148], dtype=uint8),
#   array([ 23,  26, 164], dtype=uint8),
#   array([ 15,  22, 190], dtype=uint8),
#   array([138, 173,  46], dtype=uint8),
#   array([ 24,  20, 210], dtype=uint8)],
#  [array([136, 231, 150], dtype=uint8),
#   array([ 44,  75, 102], dtype=uint8),
#   array([165,  66,  93], dtype=uint8),
#   array([ 68, 235, 168], dtype=uint8),
#   array([204,  38,  19], dtype=uint8),
#   array([ 73,  48, 249], dtype=uint8),
#   array([101,  98, 183], dtype=uint8),
#   array([ 63,  19, 134], dtype=uint8),
#   array([255, 212, 106], dtype=uint8),
#   array([248, 150,  98], dtype=uint8),
#   array([ 93, 209,  94], dtype=uint8),
#   array([145, 146, 208], dtype=uint8),
#   array([126, 133,  59], dtype=uint8),
#   array([123, 169, 217], dtype=uint8),
#   array([ 68, 171,   0], dtype=uint8),
#   array([226, 159,  26], dtype=uint8),
#   array([ 94, 148,  93], dtype=uint8),
#   array([ 53, 243, 112], dtype=uint8),
#   array([246, 123, 184], dtype=uint8),
#   array([ 58, 103,  17], dtype=uint8),
#   array([193, 177, 241], dtype=uint8),
#   array([202, 227,  65], dtype=uint8),
#   array([ 87, 243, 116], dtype=uint8),
#   array([ 70, 209,  76], dtype=uint8),
#   array([ 49, 132, 106], dtype=uint8),
#   array([221,   3, 182], dtype=uint8),
#   array([ 61, 114, 120], dtype=uint8),
#   array([ 52, 143, 193], dtype=uint8),
#   array([ 6, 13, 22], dtype=uint8),
#   array([199, 156,  54], dtype=uint8),
#   array([166, 173, 235], dtype=uint8),
#   array([255,  42,  12], dtype=uint8),
#   array([255,  41, 224], dtype=uint8),
#   array([144, 197, 150], dtype=uint8),
#   array([114, 128, 123], dtype=uint8),
#   array([ 89, 115, 108], dtype=uint8),
#   array([169,  76, 236], dtype=uint8),
#   array([125,  30, 208], dtype=uint8),
#   array([  3, 135, 112], dtype=uint8),
#   array([189, 142, 111], dtype=uint8),
#   array([183,  32, 103], dtype=uint8),
#   array([116, 163,  39], dtype=uint8),
#   array([133, 208,  75], dtype=uint8),
#   array([ 21, 181,  53], dtype=uint8),
#   array([236, 113,  27], dtype=uint8),
#   array([153, 126, 228], dtype=uint8),
#   array([192, 148,  59], dtype=uint8),
#   array([149, 163,  13], dtype=uint8),
#   array([164, 190,  74], dtype=uint8),
#   array([182,  39,  63], dtype=uint8),
#   array([199, 219, 115], dtype=uint8),
#   array([183, 234, 151], dtype=uint8),
#   array([185,  14, 200], dtype=uint8),
#   array([230,  78,  58], dtype=uint8),
#   array([193,  45,  25], dtype=uint8),
#   array([ 66,  22, 255], dtype=uint8),
#   array([  0, 116,  64], dtype=uint8),
#   array([184,  69,  13], dtype=uint8),
#   array([195,  19, 153], dtype=uint8),
#   array([245,  46, 146], dtype=uint8),
#   array([206,  56, 208], dtype=uint8),
#   array([170, 117, 150], dtype=uint8),
#   array([212,  38, 183], dtype=uint8),
#   array([217,  48,  23], dtype=uint8),
#   array([234,  44, 255], dtype=uint8),
#   array([150,  27, 152], dtype=uint8),
#   array([122, 152, 109], dtype=uint8),
#   array([ 93,  82, 225], dtype=uint8),
#   array([249, 204, 253], dtype=uint8),
#   array([151,  11, 189], dtype=uint8),
#   array([193, 127, 212], dtype=uint8),
#   array([191, 109, 184], dtype=uint8),
#   array([198, 170, 216], dtype=uint8),
#   array([228, 175,   4], dtype=uint8),
#   array([119,  84, 193], dtype=uint8),
#   array([ 17,  17, 161], dtype=uint8),
#   array([ 76,  69, 234], dtype=uint8),
#   array([ 28, 176, 227], dtype=uint8),
#   array([232, 145, 165], dtype=uint8)],
#  [array([ 19, 128,   6], dtype=uint8),
#   array([87, 81, 11], dtype=uint8),
#   array([ 86, 222,  75], dtype=uint8),
#   array([191,  24, 152], dtype=uint8),
#   array([219, 237,  69], dtype=uint8),
#   array([250, 112, 218], dtype=uint8),
#   array([ 37, 124, 169], dtype=uint8),
#   array([54, 96, 87], dtype=uint8),
#   array([  2,  23, 127], dtype=uint8),
#   array([133,  43, 124], dtype=uint8),
#   array([167,   2, 133], dtype=uint8),
#   array([104, 103, 156], dtype=uint8),
#   array([78, 72, 35], dtype=uint8),
#   array([101, 161,  30], dtype=uint8),
#   array([ 79, 162, 194], dtype=uint8),
#   array([ 89, 165, 233], dtype=uint8),
#   array([ 64, 146, 238], dtype=uint8),
#   array([ 59, 141, 237], dtype=uint8),
#   array([ 73, 150, 239], dtype=uint8),
#   array([135,   4, 104], dtype=uint8),
#   array([ 34, 159,  88], dtype=uint8),
#   array([ 42, 202,   9], dtype=uint8),
#   array([ 55, 151, 192], dtype=uint8),
#   array([ 39, 147, 137], dtype=uint8),
#   array([ 15, 109, 143], dtype=uint8),
#   array([ 52, 137, 226], dtype=uint8),
#   array([ 73, 158, 177], dtype=uint8),
#   array([ 41,  20, 236], dtype=uint8),
#   array([229, 177, 145], dtype=uint8),
#   array([234, 218,   2], dtype=uint8),
#   array([117, 152, 130], dtype=uint8),
#   array([159, 169, 174], dtype=uint8),
#   array([169, 163, 151], dtype=uint8),
#   array([134, 134,  99], dtype=uint8),
#   array([219,  27, 197], dtype=uint8),
#   array([  3, 103, 255], dtype=uint8),
#   array([ 54, 166, 200], dtype=uint8),
#   array([103, 133, 163], dtype=uint8),
#   array([  4, 129, 245], dtype=uint8),
#   array([ 95, 101,  94], dtype=uint8),
#   array([204, 223,  13], dtype=uint8),
#   array([204, 203,  16], dtype=uint8),
#   array([ 33, 224, 139], dtype=uint8),
#   array([219, 176,  36], dtype=uint8),
#   array([191,  96,   4], dtype=uint8),
#   array([193, 156,  33], dtype=uint8),
#   array([149,  41, 239], dtype=uint8),
#   array([198, 188,  68], dtype=uint8),
#   array([183, 213,  51], dtype=uint8),
#   array([229,  28, 106], dtype=uint8),
#   array([200, 101,  66], dtype=uint8),
#   array([  8,  53, 153], dtype=uint8),
#   array([ 14,  81, 192], dtype=uint8),
#   array([ 28, 128,  14], dtype=uint8),
#   array([100, 223, 185], dtype=uint8),
#   array([224,  83, 136], dtype=uint8),
#   array([13, 73, 98], dtype=uint8),
#   array([223,  23,  12], dtype=uint8),
#   array([193,  74,  20], dtype=uint8),
#   array([134, 241, 214], dtype=uint8),
#   array([174, 181,  29], dtype=uint8),
#   array([ 82, 108, 121], dtype=uint8),
#   array([ 99, 119, 145], dtype=uint8),
#   array([226,  28,   0], dtype=uint8),
#   array([ 67, 217, 232], dtype=uint8),
#   array([104,  75, 242], dtype=uint8),
#   array([160, 222, 253], dtype=uint8),
#   array([125, 236, 236], dtype=uint8),
#   array([108,  26, 224], dtype=uint8),
#   array([158, 200, 109], dtype=uint8),
#   array([ 36, 219,  86], dtype=uint8),
#   array([137,  65, 231], dtype=uint8),
#   array([246, 209, 233], dtype=uint8),
#   array([144,  60, 128], dtype=uint8),
#   array([118,  88, 177], dtype=uint8),
#   array([ 75,  48, 183], dtype=uint8),
#   array([ 77,  77, 221], dtype=uint8),
#   array([ 30, 139, 151], dtype=uint8),
#   array([137,  49, 247], dtype=uint8)],
#  [array([ 52, 155, 205], dtype=uint8),
#   array([254, 192,  12], dtype=uint8),
#   array([122, 217,  98], dtype=uint8),
#   array([ 82, 116,   0], dtype=uint8),
#   array([70, 77, 69], dtype=uint8),
#   array([ 39, 228, 108], dtype=uint8),
#   array([175,  33,  58], dtype=uint8),
#   array([189,  42,   1], dtype=uint8),
#   array([125, 203, 193], dtype=uint8),
#   array([224, 226,  66], dtype=uint8),
#   array([76,  2, 33], dtype=uint8),
#   array([159, 238,  60], dtype=uint8),
#   array([225,  23, 236], dtype=uint8),
#   array([  2,  81, 171], dtype=uint8),
#   array([199,  37,  60], dtype=uint8),
#   array([ 80, 158, 112], dtype=uint8),
#   array([ 68, 153, 194], dtype=uint8),
#   array([ 96, 153, 138], dtype=uint8),
#   array([102, 150, 236], dtype=uint8),
#   array([ 84, 154, 230], dtype=uint8),
#   array([ 94, 164, 233], dtype=uint8),
#   array([ 35, 124, 115], dtype=uint8),
#   array([ 89, 157, 240], dtype=uint8),
#   array([ 75, 146, 233], dtype=uint8),
#   array([ 72, 153, 228], dtype=uint8),
#   array([ 97, 147, 169], dtype=uint8),
#   array([ 34, 251, 159], dtype=uint8),
#   array([237, 207, 141], dtype=uint8),
#   array([203, 200, 206], dtype=uint8),
#   array([ 71,  55, 132], dtype=uint8),
#   array([184, 150, 172], dtype=uint8),
#   array([167, 153, 129], dtype=uint8),
#   array([ 95, 107,  64], dtype=uint8),
#   array([ 72, 177, 232], dtype=uint8),
#   array([ 24, 167,  34], dtype=uint8),
#   array([51, 19, 61], dtype=uint8),
#   array([ 67, 190,  90], dtype=uint8),
#   array([ 29, 255,  94], dtype=uint8),
#   array([251,  10,  21], dtype=uint8),
#   array([214, 245,  59], dtype=uint8),
#   array([191, 240,  27], dtype=uint8),
#   array([230,   1,  55], dtype=uint8),
#   array([227, 234,  77], dtype=uint8),
#   array([ 22, 225, 123], dtype=uint8),
#   array([  6,  42, 111], dtype=uint8),
#   array([ 9,  8, 73], dtype=uint8),
#   array([ 72,  99, 128], dtype=uint8),
#   array([213, 131,  46], dtype=uint8),
#   array([ 48,  68, 110], dtype=uint8),
#   array([ 53,  94, 126], dtype=uint8),
#   array([ 63, 139, 185], dtype=uint8),
#   array([ 31, 186, 132], dtype=uint8),
#   array([166, 228,  12], dtype=uint8),
#   array([181,  20,  50], dtype=uint8),
#   array([211,  64, 174], dtype=uint8),
#   array([154, 253, 208], dtype=uint8),
#   array([173,  49, 114], dtype=uint8),
#   array([235,  39,  82], dtype=uint8),
#   array([246, 132, 230], dtype=uint8),
#   array([194, 188, 163], dtype=uint8),
#   array([165, 179,  60], dtype=uint8),
#   array([134, 159,   6], dtype=uint8),
#   array([ 58, 101,  99], dtype=uint8),
#   array([ 65, 185, 122], dtype=uint8),
#   array([ 60,  34, 253], dtype=uint8),
#   array([ 69, 126, 119], dtype=uint8),
#   array([117, 242,  46], dtype=uint8),
#   array([ 11, 232,  75], dtype=uint8),
#   array([252, 120,  98], dtype=uint8),
#   array([152,  64, 164], dtype=uint8),
#   array([ 74, 248, 209], dtype=uint8),
#   array([ 69, 164, 121], dtype=uint8),
#   array([228, 151, 222], dtype=uint8),
#   array([156,  72,  67], dtype=uint8),
#   array([247, 189,  11], dtype=uint8),
#   array([160, 121, 242], dtype=uint8),
#   array([ 13,   0, 183], dtype=uint8),
#   array([226, 236, 159], dtype=uint8),
#   array([13, 18,  6], dtype=uint8)],
#  [array([ 69, 146,  92], dtype=uint8),
#   array([ 15, 145,  35], dtype=uint8),
#   array([ 38, 111, 244], dtype=uint8),
#   array([181, 189,  31], dtype=uint8),
#   array([202, 132,  89], dtype=uint8),
#   array([130, 155,  51], dtype=uint8),
#   array([  0, 101, 228], dtype=uint8),
#   array([223,  76, 183], dtype=uint8),
#   array([245,  61,  71], dtype=uint8),
#   array([114, 197, 241], dtype=uint8),
#   array([123, 201,  70], dtype=uint8),
#   array([242, 241,  29], dtype=uint8),
#   array([196,  67, 105], dtype=uint8),
#   array([ 99, 202,   2], dtype=uint8),
#   array([164, 248, 156], dtype=uint8),
#   array([159, 246, 178], dtype=uint8),
#   array([237,  54, 128], dtype=uint8),
#   array([  9,  85, 212], dtype=uint8),
#   array([100, 164, 152], dtype=uint8),
#   array([112, 172, 221], dtype=uint8),
#   array([117, 177, 240], dtype=uint8),
#   array([110, 174, 230], dtype=uint8),
#   array([106, 154, 227], dtype=uint8),
#   array([103, 163, 231], dtype=uint8),
#   array([125, 177, 201], dtype=uint8),
#   array([44, 22, 20], dtype=uint8),
#   array([210, 154,  48], dtype=uint8),
#   array([198, 175, 101], dtype=uint8),
#   array([139, 113,  67], dtype=uint8),
#   array([222, 179,  65], dtype=uint8),
#   array([205, 159, 250], dtype=uint8),
#   array([163, 143, 146], dtype=uint8),
#   array([ 66, 191,  29], dtype=uint8),
#   array([136, 198,  31], dtype=uint8),
#   array([98, 71, 78], dtype=uint8),
#   array([  1, 211,  70], dtype=uint8),
#   array([124,   2, 129], dtype=uint8),
#   array([45, 80, 56], dtype=uint8),
#   array([34, 84, 70], dtype=uint8),
#   array([36, 93, 88], dtype=uint8),
#   array([ 54, 122,  75], dtype=uint8),
#   array([ 45, 107,  78], dtype=uint8),
#   array([ 26,  60, 101], dtype=uint8),
#   array([141, 211, 216], dtype=uint8),
#   array([ 70, 134, 110], dtype=uint8),
#   array([ 97, 138, 119], dtype=uint8),
#   array([ 65,  37, 100], dtype=uint8),
#   array([149, 200, 177], dtype=uint8),
#   array([ 83, 219,  94], dtype=uint8),
#   array([  2,  30, 235], dtype=uint8),
#   array([213,  10, 223], dtype=uint8),
#   array([247,  52, 251], dtype=uint8),
#   array([ 74,  15, 132], dtype=uint8),
#   array([198,  21, 212], dtype=uint8),
#   array([212,  27,  44], dtype=uint8),
#   array([ 67, 150,   5], dtype=uint8),
#   array([173,   8,  16], dtype=uint8),
#   array([155,   0,  23], dtype=uint8),
#   array([27, 68, 63], dtype=uint8),
#   array([ 91, 143, 152], dtype=uint8),
#   array([105, 130,  13], dtype=uint8),
#   array([137, 165,  23], dtype=uint8),
#   array([101, 135, 197], dtype=uint8),
#   array([ 73, 121, 141], dtype=uint8),
#   array([206,  70,  78], dtype=uint8),
#   array([221, 245,  17], dtype=uint8),
#   array([173,  29,  89], dtype=uint8),
#   array([251, 132, 214], dtype=uint8),
#   array([194,  38,  24], dtype=uint8),
#   array([210, 193, 229], dtype=uint8),
#   array([ 92,  37, 146], dtype=uint8),
#   array([153, 101, 247], dtype=uint8),
#   array([ 61, 191, 110], dtype=uint8),
#   array([122,  99, 230], dtype=uint8),
#   array([223, 103, 127], dtype=uint8),
#   array([167, 122, 228], dtype=uint8),
#   array([ 27,   7, 193], dtype=uint8),
#   array([227, 210, 155], dtype=uint8),
#   array([22,  1,  1], dtype=uint8)],
#  [array([184, 245,  16], dtype=uint8),
#   array([ 57, 185, 115], dtype=uint8),
#   array([168, 189,  66], dtype=uint8),
#   array([104,  65, 130], dtype=uint8),
#   array([ 99, 139, 231], dtype=uint8),
#   array([ 10,  62, 111], dtype=uint8),
#   array([232,  32, 194], dtype=uint8),
#   array([ 62, 116,  14], dtype=uint8),
#   array([ 37,  89, 203], dtype=uint8),
#   array([ 79, 160,  96], dtype=uint8),
#   array([ 64, 130, 151], dtype=uint8),
#   array([ 95, 130,  35], dtype=uint8),
#   array([ 61,  31, 116], dtype=uint8),
#   array([ 92,   9, 208], dtype=uint8),
#   array([115, 217,  42], dtype=uint8),
#   array([189,  24, 117], dtype=uint8),
#   array([199,  41,  29], dtype=uint8),
#   array([ 52, 102, 173], dtype=uint8),
#   array([141, 191, 240], dtype=uint8),
#   array([149, 189, 234], dtype=uint8),
#   array([171, 187, 242], dtype=uint8),
#   array([158, 174, 235], dtype=uint8),
#   array([157, 175, 237], dtype=uint8),
#   array([153, 173, 222], dtype=uint8),
#   array([227, 243, 208], dtype=uint8),
#   array([186, 133, 186], dtype=uint8),
#   array([187, 134, 214], dtype=uint8),
#   array([213, 202, 196], dtype=uint8),
#   array([209, 181, 186], dtype=uint8),
#   array([233, 180, 231], dtype=uint8),
#   array([228, 161,  19], dtype=uint8),
#   array([152, 225, 160], dtype=uint8),
#   array([214, 102, 245], dtype=uint8),
#   array([149,  91,  34], dtype=uint8),
#   array([ 94, 103, 159], dtype=uint8),
#   array([155, 237, 247], dtype=uint8),
#   array([196, 213, 161], dtype=uint8),
#   array([115, 184, 122], dtype=uint8),
#   array([134, 219, 148], dtype=uint8),
#   array([150,   2, 146], dtype=uint8),
#   array([164,  32, 126], dtype=uint8),
#   array([167,   6, 121], dtype=uint8),
#   array([143, 234, 142], dtype=uint8),
#   array([172, 158, 226], dtype=uint8),
#   array([213,  58, 177], dtype=uint8),
#   array([218,  23, 164], dtype=uint8),
#   array([  4,  58, 207], dtype=uint8),
#   array([ 34,  74, 230], dtype=uint8),
#   array([ 62, 128, 248], dtype=uint8),
#   array([229, 238, 125], dtype=uint8),
#   array([ 98, 157,  29], dtype=uint8),
#   array([237,  23, 107], dtype=uint8),
#   array([223, 190, 100], dtype=uint8),
#   array([224,   9, 206], dtype=uint8),
#   array([224,   9, 218], dtype=uint8),
#   array([195,   5, 246], dtype=uint8),
#   array([148, 217,  30], dtype=uint8),
#   array([123, 207, 134], dtype=uint8),
#   array([ 58, 153,  92], dtype=uint8),
#   array([238, 136, 168], dtype=uint8),
#   array([ 59, 101,  14], dtype=uint8),
#   array([ 58, 120, 229], dtype=uint8),
#   array([ 62, 132, 215], dtype=uint8),
#   array([ 73, 131, 205], dtype=uint8),
#   array([206,  95, 123], dtype=uint8),
#   array([207, 176, 169], dtype=uint8),
#   array([ 96,  14, 198], dtype=uint8),
#   array([45, 62, 31], dtype=uint8),
#   array([ 98,  14, 159], dtype=uint8),
#   array([ 90, 196,  19], dtype=uint8),
#   array([192, 156, 232], dtype=uint8),
#   array([152,  84, 190], dtype=uint8),
#   array([231,  51,  35], dtype=uint8),
#   array([192, 137, 168], dtype=uint8),
#   array([ 35,  36, 160], dtype=uint8),
#   array([215, 112, 229], dtype=uint8),
#   array([ 85,  37, 220], dtype=uint8),
#   array([224, 168, 138], dtype=uint8),
#   array([51,  5,  0], dtype=uint8)],
#  [array([201, 147,  13], dtype=uint8),
#   array([ 40, 168,  81], dtype=uint8),
#   array([157, 171,  55], dtype=uint8),
#   array([153, 222, 152], dtype=uint8),
#   array([215, 239,  58], dtype=uint8),
#   array([ 34, 102,  69], dtype=uint8),
#   array([ 61, 147, 198], dtype=uint8),
#   array([231,  55, 131], dtype=uint8),
#   array([ 43, 109, 134], dtype=uint8),
#   array([239,  54, 185], dtype=uint8),
#   array([ 87, 122, 217], dtype=uint8),
#   array([97, 79, 77], dtype=uint8),
#   array([205, 119, 234], dtype=uint8),
#   array([ 41, 179, 185], dtype=uint8),
#   array([120, 232,  72], dtype=uint8),
#   array([249,  97, 111], dtype=uint8),
#   array([107, 156, 166], dtype=uint8),
#   array([161, 174, 126], dtype=uint8),
#   array([181, 195, 237], dtype=uint8),
#   array([176, 184, 236], dtype=uint8),
#   array([184, 187, 239], dtype=uint8),
#   array([190, 195, 241], dtype=uint8),
#   array([203, 196, 219], dtype=uint8),
#   array([ 15,  65, 111], dtype=uint8),
#   array([172, 196, 213], dtype=uint8),
#   array([203, 165, 190], dtype=uint8),
#   array([105, 139,   0], dtype=uint8),
#   array([199, 156, 217], dtype=uint8),
#   array([206, 172,  41], dtype=uint8),
#   array([220, 186, 227], dtype=uint8),
#   array([223,  44,   6], dtype=uint8),
#   array([131,  32, 154], dtype=uint8),
#   array([219, 153, 239], dtype=uint8),
#   array([ 96, 227, 165], dtype=uint8),
#   array([ 58, 223, 241], dtype=uint8),
#   array([228,  63,  64], dtype=uint8),
#   array([ 31,  81, 187], dtype=uint8),
#   array([237,  59, 169], dtype=uint8),
#   array([246,  79, 185], dtype=uint8),
#   array([ 23, 138, 195], dtype=uint8),
#   array([ 59, 176, 205], dtype=uint8),
#   array([127, 230, 238], dtype=uint8),
#   array([ 66, 156, 188], dtype=uint8),
#   array([ 37,  69, 227], dtype=uint8),
#   array([ 99, 164, 244], dtype=uint8),
#   array([198, 243,  26], dtype=uint8),
#   array([200, 243,  28], dtype=uint8),
#   array([159, 136, 239], dtype=uint8),
#   array([64, 12,  7], dtype=uint8),
#   array([  0, 146,  81], dtype=uint8),
#   array([120,  95, 127], dtype=uint8),
#   array([ 30, 209, 231], dtype=uint8),
#   array([119,  42,  99], dtype=uint8),
#   array([ 52, 206,  10], dtype=uint8),
#   array([194, 221,  43], dtype=uint8),
#   array([137, 150,  61], dtype=uint8),
#   array([169, 228, 144], dtype=uint8),
#   array([ 27, 130, 150], dtype=uint8),
#   array([189,  36, 129], dtype=uint8),
#   array([ 21, 141,  50], dtype=uint8),
#   array([151, 128, 213], dtype=uint8),
#   array([ 48, 117,  45], dtype=uint8),
#   array([181,  62, 175], dtype=uint8),
#   array([219, 181,  10], dtype=uint8),
#   array([213,   4,  77], dtype=uint8),
#   array([ 72,  97, 197], dtype=uint8),
#   array([127, 134, 174], dtype=uint8),
#   array([235,  12,  34], dtype=uint8),
#   array([209,  89, 169], dtype=uint8),
#   array([182, 181, 159], dtype=uint8),
#   array([138, 126, 197], dtype=uint8),
#   array([178, 101, 216], dtype=uint8),
#   array([122, 226,  46], dtype=uint8),
#   array([235, 134, 185], dtype=uint8),
#   array([158, 210, 211], dtype=uint8),
#   array([107, 232,  21], dtype=uint8),
#   array([188, 117,  10], dtype=uint8),
#   array([248, 185, 136], dtype=uint8),
#   array([129,  27,  33], dtype=uint8)],
#  [array([49, 46, 51], dtype=uint8),
#   array([ 91, 209, 113], dtype=uint8),
#   array([114, 146,  21], dtype=uint8),
#   array([175,  43,   1], dtype=uint8),
#   array([107,  22,  83], dtype=uint8),
#   array([ 29, 105, 212], dtype=uint8),
#   array([ 47, 129, 187], dtype=uint8),
#   array([188, 237, 216], dtype=uint8),
#   array([170, 238, 228], dtype=uint8),
#   array([216,  45,  23], dtype=uint8),
#   array([ 75, 178, 177], dtype=uint8),
#   array([110, 202,  72], dtype=uint8),
#   array([119, 138, 128], dtype=uint8),
#   array([222, 186, 150], dtype=uint8),
#   array([ 50, 177, 224], dtype=uint8),
#   array([139, 248, 142], dtype=uint8),
#   array([189,  12,  55], dtype=uint8),
#   array([243,  43, 238], dtype=uint8),
#   array([116, 147, 240], dtype=uint8),
#   array([212, 211, 211], dtype=uint8),
#   array([222, 202, 239], dtype=uint8),
#   array([229, 205, 232], dtype=uint8),
#   array([120, 121, 164], dtype=uint8),
#   array([172, 212, 192], dtype=uint8),
#   array([113, 114, 106], dtype=uint8),
#   array([181, 192, 162], dtype=uint8),
#   array([162, 170, 120], dtype=uint8),
#   array([  7,  29, 187], dtype=uint8),
#   array([184, 144, 134], dtype=uint8),
#   array([125, 114,  12], dtype=uint8),
#   array([238, 205,  43], dtype=uint8),
#   array([114, 247, 116], dtype=uint8),
#   array([154, 157,  18], dtype=uint8),
#   array([206,  14, 135], dtype=uint8),
#   array([192,  41, 192], dtype=uint8),
#   array([237, 216, 158], dtype=uint8),
#   array([127,  16, 237], dtype=uint8),
#   array([10, 42, 36], dtype=uint8),
#   array([238,  41,  67], dtype=uint8),
#   array([26, 86, 92], dtype=uint8),
#   array([242, 211, 149], dtype=uint8),
#   array([ 89, 131,  92], dtype=uint8),
#   array([127, 146,  87], dtype=uint8),
#   array([47, 78, 87], dtype=uint8),
#   array([207, 215, 195], dtype=uint8),
#   array([169, 107,  23], dtype=uint8),
#   array([ 30, 192,  88], dtype=uint8),
#   array([143,  98, 232], dtype=uint8),
#   array([ 61, 248,  23], dtype=uint8),
#   array([225,  98,  26], dtype=uint8),
#   array([ 29, 237,  21], dtype=uint8),
#   array([164,   4,  18], dtype=uint8),
#   array([ 43, 210, 196], dtype=uint8),
#   array([38, 50, 92], dtype=uint8),
#   array([38, 72, 81], dtype=uint8),
#   array([ 48,  52, 198], dtype=uint8),
#   array([212,  19, 157], dtype=uint8),
#   array([164, 240, 205], dtype=uint8),
#   array([107, 206, 222], dtype=uint8),
#   array([150, 250,  94], dtype=uint8),
#   array([ 23,  93, 246], dtype=uint8),
#   array([ 28, 128, 114], dtype=uint8),
#   array([172,  58, 237], dtype=uint8),
#   array([150, 148,  37], dtype=uint8),
#   array([ 70, 195, 130], dtype=uint8),
#   array([238, 124, 207], dtype=uint8),
#   array([ 24,  77, 142], dtype=uint8),
#   array([216,   8,  99], dtype=uint8),
#   array([ 85, 159,  12], dtype=uint8),
#   array([206,   1, 128], dtype=uint8),
#   array([125, 130,  38], dtype=uint8),
#   array([ 91, 162, 146], dtype=uint8),
#   array([ 55, 243, 144], dtype=uint8),
#   array([102, 147, 205], dtype=uint8),
#   array([ 8, 46, 85], dtype=uint8),
#   array([155,  93,   4], dtype=uint8),
#   array([255, 141,  21], dtype=uint8),
#   array([ 26, 197, 159], dtype=uint8),
#   array([176, 103,  70], dtype=uint8)],
#  [array([113,  15,   4], dtype=uint8),
#   array([173,  13, 179], dtype=uint8),
#   array([228,  40, 187], dtype=uint8),
#   array([ 95, 117, 186], dtype=uint8),
#   array([139,  49,  84], dtype=uint8),
#   array([ 55, 152, 166], dtype=uint8),
#   array([117, 153, 154], dtype=uint8),
#   array([188, 172, 190], dtype=uint8),
#   array([164, 164, 187], dtype=uint8),
#   array([ 35, 138, 117], dtype=uint8),
#   array([224,  76,  52], dtype=uint8),
#   array([244, 105,  75], dtype=uint8),
#   array([ 17, 135,  43], dtype=uint8),
#   array([169,  31, 116], dtype=uint8),
#   array([ 49, 151, 125], dtype=uint8),
#   array([ 60,  31, 240], dtype=uint8),
#   array([ 11, 145, 236], dtype=uint8),
#   array([125, 231, 112], dtype=uint8),
#   array([ 24,  86, 242], dtype=uint8),
#   array([190, 200, 206], dtype=uint8),
#   array([219, 217, 223], dtype=uint8),
#   array([ 90,  92, 185], dtype=uint8),
#   array([70, 87, 20], dtype=uint8),
#   array([ 91, 152, 121], dtype=uint8),
#   array([187, 174, 135], dtype=uint8),
#   array([183, 199, 127], dtype=uint8),
#   array([161, 186,  46], dtype=uint8),
#   array([150, 170, 107], dtype=uint8),
#   array([ 90, 119,   9], dtype=uint8),
#   array([191,  85,  81], dtype=uint8),
#   array([ 95, 177, 153], dtype=uint8),
#   array([  7,  87, 227], dtype=uint8),
#   array([ 93,   3, 196], dtype=uint8),
#   array([ 56, 221, 154], dtype=uint8),
#   array([229,  15,  66], dtype=uint8),
#   array([211, 163, 118], dtype=uint8),
#   array([198, 147, 102], dtype=uint8),
#   array([166,  17, 199], dtype=uint8),
#   array([ 93, 243, 174], dtype=uint8),
#   array([170,  91,  49], dtype=uint8),
#   array([ 80, 243,  27], dtype=uint8),
#   array([155,  19, 187], dtype=uint8),
#   array([142, 253, 173], dtype=uint8),
#   array([217, 154, 116], dtype=uint8),
#   array([ 23, 169, 224], dtype=uint8),
#   array([ 79, 197,  61], dtype=uint8),
#   array([ 48, 151, 237], dtype=uint8),
#   array([120,   5, 125], dtype=uint8),
#   array([161,   8,  74], dtype=uint8),
#   array([200, 179, 111], dtype=uint8),
# ...
#   array([132,  43, 240], dtype=uint8),
#   array([223,   1, 253], dtype=uint8),
#   array([17, 13, 78], dtype=uint8),
#   array([172,   1,  91], dtype=uint8),
#   array([ 32,  27, 237], dtype=uint8),
#   array([14, 51, 32], dtype=uint8),
#   array([123,  24,  54], dtype=uint8),
#   array([254, 174, 192], dtype=uint8),
#   array([ 15, 209, 191], dtype=uint8),
#   array([248, 176, 161], dtype=uint8),
#   array([155,  19, 252], dtype=uint8),
#   array([ 75, 176, 179], dtype=uint8),
#   array([ 75, 101, 115], dtype=uint8),
#   array([151,  28, 155], dtype=uint8),
#   array([73, 14, 81], dtype=uint8),
#   array([127, 184,  52], dtype=uint8)],
#  [array([ 80, 243,  40], dtype=uint8),
#   array([ 68, 172, 237], dtype=uint8),
#   array([158,  86,  28], dtype=uint8),
#   array([158,  45,  65], dtype=uint8),
#   array([ 26, 140, 255], dtype=uint8),
#   array([215, 169, 214], dtype=uint8),
#   array([93,  2, 19], dtype=uint8),
#   array([199,  42, 111], dtype=uint8),
#   array([160,  40, 178], dtype=uint8),
#   array([ 37, 101,   8], dtype=uint8),
#   array([119, 166,  72], dtype=uint8),
#   array([ 73, 171,  56], dtype=uint8),
#   array([220, 185, 153], dtype=uint8),
#   array([222, 194, 176], dtype=uint8),
#   array([ 75, 113,  68], dtype=uint8),
#   array([229, 154, 188], dtype=uint8),
#   array([172, 226,  53], dtype=uint8),
#   array([ 79,  36, 142], dtype=uint8),
#   array([138, 221, 158], dtype=uint8),
#   array([241, 132, 175], dtype=uint8),
#   array([177, 134, 225], dtype=uint8),
#   array([122, 252,  90], dtype=uint8),
#   array([218, 133, 141], dtype=uint8),
#   array([225,  16,  39], dtype=uint8),
#   array([97, 61, 11], dtype=uint8),
#   array([190, 168,  86], dtype=uint8),
#   array([229,  41, 125], dtype=uint8),
#   array([176,  68, 236], dtype=uint8),
#   array([192, 150,  72], dtype=uint8),
#   array([ 99,  65, 211], dtype=uint8),
#   array([ 93,  29, 202], dtype=uint8),
#   array([207, 154,  34], dtype=uint8),
#   array([249, 207, 103], dtype=uint8),
#   array([154,  82, 217], dtype=uint8),
#   array([ 78,  31, 159], dtype=uint8),
#   array([ 43,  25, 193], dtype=uint8),
#   array([126,  89, 181], dtype=uint8),
#   array([183, 149, 232], dtype=uint8),
#   array([ 10,  11, 109], dtype=uint8),
#   array([104,  58, 206], dtype=uint8),
#   array([156, 116, 227], dtype=uint8),
#   array([141, 137,  54], dtype=uint8),
#   array([ 95,  46, 188], dtype=uint8),
#   array([ 64,  15, 145], dtype=uint8),
#   array([205,   5, 224], dtype=uint8),
#   array([ 57, 102,  56], dtype=uint8),
#   array([210,   4, 197], dtype=uint8),
#   array([243, 250, 178], dtype=uint8),
#   array([  1, 201,  61], dtype=uint8),
#   array([191, 107, 215], dtype=uint8),
#   array([234, 168, 251], dtype=uint8),
#   array([ 89,  33, 125], dtype=uint8),
#   array([ 62, 252,  62], dtype=uint8),
#   array([66, 16, 70], dtype=uint8),
#   array([ 26,   0, 206], dtype=uint8),
#   array([151, 116,  47], dtype=uint8),
#   array([164, 169, 184], dtype=uint8),
#   array([163, 195,  42], dtype=uint8),
#   array([173,  10, 185], dtype=uint8),
#   array([204,  80,   1], dtype=uint8),
#   array([215, 104,  85], dtype=uint8),
#   array([106,   7, 246], dtype=uint8),
#   array([170,  48,  80], dtype=uint8),
#   array([128, 251, 227], dtype=uint8),
#   array([197,  47,  43], dtype=uint8),
#   array([ 66, 194, 213], dtype=uint8),
#   array([ 23, 223,  99], dtype=uint8),
#   array([ 60,   3, 154], dtype=uint8),
#   array([251, 216,  78], dtype=uint8),
#   array([ 30, 237, 243], dtype=uint8),
#   array([ 23, 234, 251], dtype=uint8),
#   array([247, 207, 214], dtype=uint8),
#   array([159, 104,  82], dtype=uint8),
#   array([168,  46,  22], dtype=uint8),
#   array([  9,  68, 207], dtype=uint8),
#   array([ 65,  84, 210], dtype=uint8),
#   array([ 85, 185, 240], dtype=uint8),
#   array([244,  49, 210], dtype=uint8),
#   array([174, 219, 133], dtype=uint8)],
#  [array([ 56,  55, 156], dtype=uint8),
#   array([ 80, 149, 245], dtype=uint8),
#   array([248, 172, 169], dtype=uint8),
#   array([104,  59,  32], dtype=uint8),
#   array([178,  12, 251], dtype=uint8),
#   array([193,  11, 116], dtype=uint8),
#   array([115, 230,  31], dtype=uint8),
#   array([246,  75, 108], dtype=uint8),
#   array([ 86, 168, 164], dtype=uint8),
#   array([186, 220,  63], dtype=uint8),
#   array([ 29, 109, 157], dtype=uint8),
#   array([229, 205, 202], dtype=uint8),
#   array([226, 184, 188], dtype=uint8),
#   array([13, 29, 29], dtype=uint8),
#   array([205,  85, 251], dtype=uint8),
#   array([217, 175, 179], dtype=uint8),
#   array([233,   8,  22], dtype=uint8),
#   array([216, 176,  71], dtype=uint8),
#   array([120,  33, 192], dtype=uint8),
#   array([173, 140,   4], dtype=uint8),
#   array([195, 164,  73], dtype=uint8),
#   array([234, 131, 177], dtype=uint8),
#   array([234,   3, 101], dtype=uint8),
#   array([109, 193, 243], dtype=uint8),
#   array([180, 239, 178], dtype=uint8),
#   array([120,  93,  83], dtype=uint8),
#   array([227,  47, 105], dtype=uint8),
#   array([199,  74, 203], dtype=uint8),
#   array([ 88,  28, 201], dtype=uint8),
#   array([154, 111, 233], dtype=uint8),
#   array([155, 132,  65], dtype=uint8),
#   array([250, 190,  68], dtype=uint8),
#   array([237, 190,  84], dtype=uint8),
#   array([220, 151,  24], dtype=uint8),
#   array([ 74,  18, 114], dtype=uint8),
#   array([ 40,  38, 185], dtype=uint8),
#   array([ 44, 249, 113], dtype=uint8),
#   array([195, 149, 238], dtype=uint8),
#   array([185, 139, 228], dtype=uint8),
#   array([127, 176, 100], dtype=uint8),
#   array([116,  88, 168], dtype=uint8),
#   array([ 43,  37, 173], dtype=uint8),
#   array([217, 208,  91], dtype=uint8),
#   array([ 95,  65, 144], dtype=uint8),
#   array([154, 180, 100], dtype=uint8),
#   array([ 64, 112, 155], dtype=uint8),
#   array([189, 241, 174], dtype=uint8),
#   array([145, 140,  30], dtype=uint8),
#   array([235, 178,  14], dtype=uint8),
#   array([148,  65, 170], dtype=uint8),
#   array([ 80,  14, 113], dtype=uint8),
#   array([217, 158, 219], dtype=uint8),
#   array([61,  2, 60], dtype=uint8),
#   array([  9, 209,  23], dtype=uint8),
#   array([236, 183, 122], dtype=uint8),
#   array([184, 136,   5], dtype=uint8),
#   array([159, 139,  83], dtype=uint8),
#   array([238,  11,  43], dtype=uint8),
#   array([ 38, 106, 155], dtype=uint8),
#   array([ 17, 123,  49], dtype=uint8),
#   array([188,  70,   8], dtype=uint8),
#   array([ 39, 200, 163], dtype=uint8),
#   array([181,  67,  20], dtype=uint8),
#   array([120,  59,  41], dtype=uint8),
#   array([ 86, 195, 183], dtype=uint8),
#   array([ 45, 128,  41], dtype=uint8),
#   array([ 93, 167,  66], dtype=uint8),
#   array([ 96, 171,  58], dtype=uint8),
#   array([ 75, 183,  52], dtype=uint8),
#   array([192, 216,  43], dtype=uint8),
#   array([ 60, 147, 217], dtype=uint8),
#   array([229,  87, 101], dtype=uint8),
#   array([ 40,  72, 225], dtype=uint8),
#   array([244, 117, 178], dtype=uint8),
#   array([219, 249, 237], dtype=uint8),
#   array([ 41, 111,   9], dtype=uint8),
#   array([111, 130,  60], dtype=uint8),
#   array([12, 71, 26], dtype=uint8),
#   array([186, 235, 195], dtype=uint8)],
#  [array([ 57, 117, 182], dtype=uint8),
#   array([200, 245, 214], dtype=uint8),
#   array([93, 28, 83], dtype=uint8),
#   array([ 27,  13, 247], dtype=uint8),
#   array([108, 104,  76], dtype=uint8),
#   array([161,  63,  58], dtype=uint8),
#   array([142, 106, 218], dtype=uint8),
#   array([ 94, 198,  22], dtype=uint8),
#   array([32, 67,  3], dtype=uint8),
#   array([ 15, 171, 234], dtype=uint8),
#   array([242, 187, 189], dtype=uint8),
#   array([233, 178, 185], dtype=uint8),
#   array([44,  7, 38], dtype=uint8),
#   array([146,  35, 120], dtype=uint8),
#   array([222, 161, 168], dtype=uint8),
#   array([237,  97, 136], dtype=uint8),
#   array([155, 167,  42], dtype=uint8),
#   array([146, 172,  33], dtype=uint8),
#   array([197, 147,  23], dtype=uint8),
#   array([243,  68,  79], dtype=uint8),
#   array([ 25,  89, 203], dtype=uint8),
#   array([239, 105, 177], dtype=uint8),
#   array([ 21, 215, 135], dtype=uint8),
#   array([166,  34,  46], dtype=uint8),
#   array([ 14, 168,  85], dtype=uint8),
#   array([ 84, 169,  22], dtype=uint8),
#   array([188,  14, 110], dtype=uint8),
#   array([145,  73, 162], dtype=uint8),
#   array([121,  62, 193], dtype=uint8),
#   array([171, 115, 237], dtype=uint8),
#   array([121, 148, 103], dtype=uint8),
#   array([197, 141,   7], dtype=uint8),
#   array([248, 190,  62], dtype=uint8),
#   array([216, 174,  62], dtype=uint8),
#   array([ 73,  31, 118], dtype=uint8),
#   array([ 51,   9, 110], dtype=uint8),
#   array([ 11,  15, 192], dtype=uint8),
#   array([118,  73, 179], dtype=uint8),
#   array([184, 128, 220], dtype=uint8),
#   array([236, 222,  35], dtype=uint8),
#   array([ 25,  18, 166], dtype=uint8),
#   array([ 64,  31, 126], dtype=uint8),
#   array([ 88,  88, 224], dtype=uint8),
#   array([ 66,  31, 128], dtype=uint8),
#   array([ 75,  72, 230], dtype=uint8),
#   array([254,  28,  93], dtype=uint8),
#   array([44, 93, 11], dtype=uint8),
#   array([157, 148,  13], dtype=uint8),
#   array([172, 111, 205], dtype=uint8),
#   array([209, 148, 242], dtype=uint8),
#   array([ 94,  19, 100], dtype=uint8),
#   array([ 52, 238,  28], dtype=uint8),
#   array([ 67, 253,  63], dtype=uint8),
#   array([145,  71, 184], dtype=uint8),
#   array([182, 103, 235], dtype=uint8),
#   array([236, 173,  60], dtype=uint8),
#   array([241, 207, 129], dtype=uint8),
#   array([251,  23,  49], dtype=uint8),
#   array([183, 217,  73], dtype=uint8),
#   array([222,  27, 180], dtype=uint8),
#   array([217,  64, 227], dtype=uint8),
#   array([ 97, 217, 128], dtype=uint8),
#   array([133,  51,  13], dtype=uint8),
#   array([240, 154,  93], dtype=uint8),
#   array([143,  29, 194], dtype=uint8),
#   array([ 90, 228, 107], dtype=uint8),
#   array([239,  91, 247], dtype=uint8),
#   array([100, 189,  41], dtype=uint8),
#   array([132, 206,  35], dtype=uint8),
#   array([142, 209,  64], dtype=uint8),
#   array([158, 208,  69], dtype=uint8),
#   array([170, 216,  54], dtype=uint8),
#   array([162, 206,  26], dtype=uint8),
#   array([202,  50, 228], dtype=uint8),
#   array([114,  21, 212], dtype=uint8),
#   array([ 40,   5, 181], dtype=uint8),
#   array([136, 122,  65], dtype=uint8),
#   array([ 32, 108,  93], dtype=uint8),
#   array([249,  69,  54], dtype=uint8)],
#  [array([119,  84, 167], dtype=uint8),
#   array([172, 113, 252], dtype=uint8),
#   array([237,  65,  21], dtype=uint8),
#   array([122,  65, 149], dtype=uint8),
#   array([ 5,  7, 50], dtype=uint8),
#   array([197, 140, 157], dtype=uint8),
#   array([252, 163,  36], dtype=uint8),
#   array([210, 211, 188], dtype=uint8),
#   array([215, 108,  46], dtype=uint8),
#   array([234, 190, 170], dtype=uint8),
#   array([237, 177, 196], dtype=uint8),
#   array([197,  14, 216], dtype=uint8),
#   array([ 51, 177,  65], dtype=uint8),
#   array([133, 206,  26], dtype=uint8),
#   array([235, 141, 149], dtype=uint8),
#   array([163, 112, 250], dtype=uint8),
#   array([34, 77,  9], dtype=uint8),
#   array([ 87, 139,   4], dtype=uint8),
#   array([104,  29, 199], dtype=uint8),
#   array([ 92, 192,  51], dtype=uint8),
#   array([235,  79, 213], dtype=uint8),
#   array([242,  90, 160], dtype=uint8),
#   array([ 62, 240, 203], dtype=uint8),
#   array([ 12, 106, 152], dtype=uint8),
#   array([168, 113,  61], dtype=uint8),
#   array([ 52, 224, 146], dtype=uint8),
#   array([205,  81, 223], dtype=uint8),
#   array([59,  3, 89], dtype=uint8),
#   array([166, 110, 222], dtype=uint8),
#   array([ 97,  39, 152], dtype=uint8),
#   array([184, 229, 135], dtype=uint8),
#   array([226, 197,  87], dtype=uint8),
#   array([212, 175,  23], dtype=uint8),
#   array([222, 185,  36], dtype=uint8),
#   array([108,  64, 186], dtype=uint8),
#   array([ 87,  53, 122], dtype=uint8),
#   array([226, 225, 105], dtype=uint8),
#   array([189, 189,  76], dtype=uint8),
#   array([143,  87, 159], dtype=uint8),
#   array([137,  74, 140], dtype=uint8),
#   array([ 92, 154,  56], dtype=uint8),
#   array([223, 203,  70], dtype=uint8),
#   array([ 36,  33, 168], dtype=uint8),
#   array([121, 109, 225], dtype=uint8),
#   array([186, 198,  26], dtype=uint8),
#   array([196, 233,  64], dtype=uint8),
#   array([ 86, 117,  33], dtype=uint8),
#   array([ 94,  93, 247], dtype=uint8),
#   array([  4, 217, 107], dtype=uint8),
#   array([172, 116, 210], dtype=uint8),
#   array([246, 176, 229], dtype=uint8),
#   array([ 70, 217,  26], dtype=uint8),
#   array([ 59, 245,  50], dtype=uint8),
#   array([234, 164, 249], dtype=uint8),
#   array([241, 167,  12], dtype=uint8),
#   array([228, 172,  38], dtype=uint8),
#   array([245, 224, 111], dtype=uint8),
#   array([21, 37, 75], dtype=uint8),
#   array([202, 209,  96], dtype=uint8),
#   array([ 51, 144,  28], dtype=uint8),
#   array([109, 207,  77], dtype=uint8),
#   array([ 32, 134,  12], dtype=uint8),
#   array([ 81, 222, 122], dtype=uint8),
#   array([212, 143,  94], dtype=uint8),
#   array([232, 178,  27], dtype=uint8),
#   array([159,  55, 111], dtype=uint8),
#   array([206,  31,  77], dtype=uint8),
#   array([192,   7,  79], dtype=uint8),
#   array([ 93, 158,  26], dtype=uint8),
#   array([135, 195,  31], dtype=uint8),
#   array([197, 227,  39], dtype=uint8),
#   array([29, 46, 51], dtype=uint8),
#   array([246,  12,  28], dtype=uint8),
#   array([213, 238,  51], dtype=uint8),
#   array([251,  21,  53], dtype=uint8),
#   array([222, 253,  27], dtype=uint8),
#   array([157, 225, 201], dtype=uint8),
#   array([208,  23,   7], dtype=uint8),
#   array([ 26, 122, 121], dtype=uint8)],
#  [array([146, 178, 227], dtype=uint8),
#   array([ 70,  13, 155], dtype=uint8),
#   array([ 55, 237,  66], dtype=uint8),
#   array([129, 154, 120], dtype=uint8),
#   array([128,  14, 197], dtype=uint8),
#   array([111, 104, 186], dtype=uint8),
#   array([ 24, 209,  86], dtype=uint8),
#   array([201, 213,  46], dtype=uint8),
#   array([231, 167, 181], dtype=uint8),
#   array([223, 174, 158], dtype=uint8),
#   array([194, 169,  19], dtype=uint8),
#   array([  5, 154,  29], dtype=uint8),
#   array([169, 188, 198], dtype=uint8),
#   array([236, 148, 142], dtype=uint8),
#   array([242, 103, 158], dtype=uint8),
#   array([152, 219,   8], dtype=uint8),
#   array([213,  49, 231], dtype=uint8),
#   array([ 20, 136,   5], dtype=uint8),
#   array([113,  38, 250], dtype=uint8),
#   array([120,  22, 145], dtype=uint8),
#   array([239,  97, 204], dtype=uint8),
#   array([236,  66, 125], dtype=uint8),
#   array([129,  35,  45], dtype=uint8),
#   array([208,  13,  76], dtype=uint8),
#   array([ 67,  42, 223], dtype=uint8),
#   array([159, 127,  49], dtype=uint8),
#   array([195, 136,  29], dtype=uint8),
#   array([178, 125, 225], dtype=uint8),
#   array([ 87,  33, 126], dtype=uint8),
#   array([ 60,  18, 105], dtype=uint8),
#   array([ 78,  88, 192], dtype=uint8),
#   array([208, 242, 140], dtype=uint8),
#   array([ 93,  57, 177], dtype=uint8),
#   array([242, 210,  36], dtype=uint8),
#   array([205, 174,   7], dtype=uint8),
#   array([242, 197,  53], dtype=uint8),
#   array([ 20, 248,  60], dtype=uint8),
#   array([ 18,  33, 188], dtype=uint8),
#   array([ 50,  18, 120], dtype=uint8),
#   array([100,  50, 141], dtype=uint8),
#   array([ 72,  48, 112], dtype=uint8),
#   array([207,   6, 171], dtype=uint8),
#   array([121, 127,  16], dtype=uint8),
#   array([ 45,  40, 215], dtype=uint8),
#   array([230,   6, 148], dtype=uint8),
#   array([204,  30, 131], dtype=uint8),
#   array([ 89, 131,  53], dtype=uint8),
#   array([ 29,  43, 201], dtype=uint8),
#   array([248, 239, 108], dtype=uint8),
#   array([101,  34, 106], dtype=uint8),
#   array([224, 154, 217], dtype=uint8),
#   array([ 28, 205,   4], dtype=uint8),
#   array([ 25, 211,   7], dtype=uint8),
#   array([  6, 195, 250], dtype=uint8),
#   array([249, 174,   8], dtype=uint8),
#   array([197, 141, 239], dtype=uint8),
#   array([202, 196,  94], dtype=uint8),
#   array([15, 43, 66], dtype=uint8),
#   array([252,  17,  44], dtype=uint8),
#   array([ 39, 156,   6], dtype=uint8),
#   array([  5, 103, 201], dtype=uint8),
#   array([239,  95, 227], dtype=uint8),
#   array([  2, 135,   5], dtype=uint8),
#   array([ 63, 218, 119], dtype=uint8),
#   array([121,  35, 229], dtype=uint8),
#   array([138, 156, 205], dtype=uint8),
#   array([156, 189, 170], dtype=uint8),
#   array([ 54, 149, 143], dtype=uint8),
#   array([158,  36,   4], dtype=uint8),
#   array([ 43, 148, 185], dtype=uint8),
#   array([120, 185, 227], dtype=uint8),
#   array([215, 245,  21], dtype=uint8),
#   array([225, 243,   0], dtype=uint8),
#   array([204, 219,  41], dtype=uint8),
#   array([247,   2,  28], dtype=uint8),
#   array([231, 232,  42], dtype=uint8),
#   array([241,   3,  48], dtype=uint8),
#   array([231,   0,  64], dtype=uint8),
#   array([201, 225,  61], dtype=uint8)]]

# %%
track = len(ni)

# %%
#turn image rgb 3channel into 1channel (mode==sum==combine)
i1 = range(len(ni))
j1 = range(len(ni[0]))
k1 = range(len(ni[0][0]))
for i in i1:
  for j in j1:
    sum_ = 0
    for k in range(3):
      sum_ += ni[i][j][k]
    ni[i][j] = sum_
# Out:
# C:\Users\原神\AppData\Local\Temp\ipykernel_12500\3805983769.py:9: RuntimeWarning: overflow encountered in scalar add
#   sum_ += ni[i][j][k]

# %%
import math
mean = math.fsum(n)/len(n) #key values average

# %%
#scale image data into note keys
i1 = range(len(ni))
j1 = range(len(ni[0]))
for i in i1:
  smean = math.fsum([i for i in ni[i]])/len(ni[i])
  for j in j1:
    ni[i][j] *= mean/smean

# %%
#upper and lower check
i1 = range(len(ni))
j1 = range(len(ni[0]))
for i in i1:
  for j in j1:
    ni[i][j] = int(ni[i][j])
    if ni[i][j]>u:
      ni[i][j] = u
    if ni[i][j]<l:
      ni[i][j] = l

# %%
#basic create
channel = 0
time = 0  # In beats
duration = 1  # In beats
tempo = 60  # In BPM
velocity = 100  # 0-127, as per the MIDI standard - often used for VOLUME

MyMIDI = MIDIFile(track)
MyMIDI.add_tempo(0, time, tempo)

# %%
#write track==image height, pitch==image width scale value
for index, items in enumerate(ni):
    for j, pitch in enumerate(items):
        MyMIDI.add_note(index, channel, pitch, time + j, duration, velocity)

# %%
#output
with open("202510291245.mid", "wb") as output_file:
    MyMIDI.write_file(output_file)
